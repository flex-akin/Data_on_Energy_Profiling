# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("OSU001.csv")

# %%
df
# Out:
#         2020-12-20 12:39:0     nan  220.80  49.80  0.00  0.00.1
# 0                      NaN   0.090     NaN    NaN   NaN     NaN
# 1       2020-12-20 12:39:1     NaN   220.7   49.8  0.00     0.0
# 2                      NaN   0.090     NaN    NaN   NaN     NaN
# 3       2020-12-20 12:39:2     NaN   220.7   49.8  0.00     0.0
# 4                      NaN   0.090     NaN    NaN   NaN     NaN
# ...                    ...     ...     ...    ...   ...     ...
# 686144                 NaN  15.654     NaN    NaN   NaN     NaN
# 686145    2020-9-23 5:34:5   1.799   185.6   50.0  0.98   332.7
# 686146                 NaN  15.654     NaN    NaN   NaN     NaN
# 686147    2020-9-23 5:34:6   1.803   186.4   50.0  0.98   334.9
# 686148                 NaN   1.000     NaN    NaN   NaN     NaN
#
# [686149 rows x 6 columns]

# %%
df = df.rename({'2020-12-20 12:39:0': 'Date', 'nan': 'Current', '220.80' : 'Voltage', '49.80' : 'Frequency', '0.00' : 'Power Factor' , '0.00.1' : 'Power'}, axis=1)

# %%
df
# Out:
#                       Date  Current  Voltage  Frequency  Power Factor  Power
# 0                      NaN    0.090      NaN        NaN           NaN    NaN
# 1       2020-12-20 12:39:1      NaN    220.7       49.8          0.00    0.0
# 2                      NaN    0.090      NaN        NaN           NaN    NaN
# 3       2020-12-20 12:39:2      NaN    220.7       49.8          0.00    0.0
# 4                      NaN    0.090      NaN        NaN           NaN    NaN
# ...                    ...      ...      ...        ...           ...    ...
# 686144                 NaN   15.654      NaN        NaN           NaN    NaN
# 686145    2020-9-23 5:34:5    1.799    185.6       50.0          0.98  332.7
# 686146                 NaN   15.654      NaN        NaN           NaN    NaN
# 686147    2020-9-23 5:34:6    1.803    186.4       50.0          0.98  334.9
# 686148                 NaN    1.000      NaN        NaN           NaN    NaN
#
# [686149 rows x 6 columns]

# %%
rng = range(0, 686149, 2)
odd_rows = df.iloc[rng]

# %%
df.drop(rng, inplace=True)

# %%
odd_rows
# Out:
#        Date  Current  Voltage  Frequency  Power Factor  Power
# 0       NaN    0.090      NaN        NaN           NaN    NaN
# 2       NaN    0.090      NaN        NaN           NaN    NaN
# 4       NaN    0.090      NaN        NaN           NaN    NaN
# 6       NaN    0.090      NaN        NaN           NaN    NaN
# 8       NaN    0.090      NaN        NaN           NaN    NaN
# ...     ...      ...      ...        ...           ...    ...
# 686140  NaN   15.654      NaN        NaN           NaN    NaN
# 686142  NaN   15.654      NaN        NaN           NaN    NaN
# 686144  NaN   15.654      NaN        NaN           NaN    NaN
# 686146  NaN   15.654      NaN        NaN           NaN    NaN
# 686148  NaN    1.000      NaN        NaN           NaN    NaN
#
# [343075 rows x 6 columns]

# %%
odd_rows.drop(0, inplace=True)

# %%
odd_rows
# Out:
#        Date  Current  Voltage  Frequency  Power Factor  Power
# 2       NaN    0.090      NaN        NaN           NaN    NaN
# 4       NaN    0.090      NaN        NaN           NaN    NaN
# 6       NaN    0.090      NaN        NaN           NaN    NaN
# 8       NaN    0.090      NaN        NaN           NaN    NaN
# 10      NaN    0.090      NaN        NaN           NaN    NaN
# ...     ...      ...      ...        ...           ...    ...
# 686140  NaN   15.654      NaN        NaN           NaN    NaN
# 686142  NaN   15.654      NaN        NaN           NaN    NaN
# 686144  NaN   15.654      NaN        NaN           NaN    NaN
# 686146  NaN   15.654      NaN        NaN           NaN    NaN
# 686148  NaN    1.000      NaN        NaN           NaN    NaN
#
# [343074 rows x 6 columns]

# %%
odd_rows.drop(['Voltage', 'Frequency', 'Power Factor', 'Power', 'Date'], axis=1 , inplace=True)

# %%
odd_rows
# Out:
#        Date  Current  Voltage  Frequency  Power Factor  Power
# 2       NaN    0.090      NaN        NaN           NaN    NaN
# 4       NaN    0.090      NaN        NaN           NaN    NaN
# 6       NaN    0.090      NaN        NaN           NaN    NaN
# 8       NaN    0.090      NaN        NaN           NaN    NaN
# 10      NaN    0.090      NaN        NaN           NaN    NaN
# ...     ...      ...      ...        ...           ...    ...
# 686140  NaN   15.654      NaN        NaN           NaN    NaN
# 686142  NaN   15.654      NaN        NaN           NaN    NaN
# 686144  NaN   15.654      NaN        NaN           NaN    NaN
# 686146  NaN   15.654      NaN        NaN           NaN    NaN
# 686148  NaN    1.000      NaN        NaN           NaN    NaN
#
# [343074 rows x 6 columns]

# %%
odd_rows.rename({'Current' : 'Energy'}, axis=1 , inplace=True)

# %%
df
# Out:
#                       Date  Current  Voltage  Frequency  Power Factor  Power
# 1       2020-12-20 12:39:1      NaN    220.7       49.8          0.00    0.0
# 3       2020-12-20 12:39:2      NaN    220.7       49.8          0.00    0.0
# 5       2020-12-20 12:39:3      NaN    220.7       49.8          0.00    0.0
# 7       2020-12-20 12:39:4      NaN    220.7       49.8          0.00    0.0
# 9       2020-12-20 12:39:5    0.035    220.8       49.8          0.14    2.0
# ...                    ...      ...      ...        ...           ...    ...
# 686139    2020-9-23 5:34:2    1.813    188.3       50.0          0.98  340.1
# 686141    2020-9-23 5:34:3    1.801    185.6       50.0          0.98  333.0
# 686143    2020-9-23 5:34:4    1.796    184.8       50.0          0.98  330.7
# 686145    2020-9-23 5:34:5    1.799    185.6       50.0          0.98  332.7
# 686147    2020-9-23 5:34:6    1.803    186.4       50.0          0.98  334.9
#
# [343074 rows x 6 columns]

# %%
odd_rows
# Out:
#        Date  Energy  Voltage  Frequency  Power Factor  Power
# 2       NaN   0.090      NaN        NaN           NaN    NaN
# 4       NaN   0.090      NaN        NaN           NaN    NaN
# 6       NaN   0.090      NaN        NaN           NaN    NaN
# 8       NaN   0.090      NaN        NaN           NaN    NaN
# 10      NaN   0.090      NaN        NaN           NaN    NaN
# ...     ...     ...      ...        ...           ...    ...
# 686140  NaN  15.654      NaN        NaN           NaN    NaN
# 686142  NaN  15.654      NaN        NaN           NaN    NaN
# 686144  NaN  15.654      NaN        NaN           NaN    NaN
# 686146  NaN  15.654      NaN        NaN           NaN    NaN
# 686148  NaN   1.000      NaN        NaN           NaN    NaN
#
# [343074 rows x 6 columns]

# %%
pd.reset_index(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-616483eb7be1> in <module>
# ----> 1 pd.reset_index(df)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'reset_index'

# %%
df.reset_index()
# Out:
#          index                Date  Current  Voltage  Frequency  Power Factor  \
# 0            1  2020-12-20 12:39:1      NaN    220.7       49.8          0.00
# 1            3  2020-12-20 12:39:2      NaN    220.7       49.8          0.00
# 2            5  2020-12-20 12:39:3      NaN    220.7       49.8          0.00
# 3            7  2020-12-20 12:39:4      NaN    220.7       49.8          0.00
# 4            9  2020-12-20 12:39:5    0.035    220.8       49.8          0.14
# ...        ...                 ...      ...      ...        ...           ...
# 343069  686139    2020-9-23 5:34:2    1.813    188.3       50.0          0.98
# 343070  686141    2020-9-23 5:34:3    1.801    185.6       50.0          0.98
# 343071  686143    2020-9-23 5:34:4    1.796    184.8       50.0          0.98
# 343072  686145    2020-9-23 5:34:5    1.799    185.6       50.0          0.98
# 343073  686147    2020-9-23 5:34:6    1.803    186.4       50.0          0.98
#
#         Power
# 0         0.0
# ...

# %%
odd_rows.reset_index(drop=True, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                       Date  Current  Voltage  Frequency  Power Factor  Power
# 0       2020-12-20 12:39:1      NaN    220.7       49.8          0.00    0.0
# 1       2020-12-20 12:39:2      NaN    220.7       49.8          0.00    0.0
# 2       2020-12-20 12:39:3      NaN    220.7       49.8          0.00    0.0
# 3       2020-12-20 12:39:4      NaN    220.7       49.8          0.00    0.0
# 4       2020-12-20 12:39:5    0.035    220.8       49.8          0.14    2.0
# ...                    ...      ...      ...        ...           ...    ...
# 343069    2020-9-23 5:34:2    1.813    188.3       50.0          0.98  340.1
# 343070    2020-9-23 5:34:3    1.801    185.6       50.0          0.98  333.0
# 343071    2020-9-23 5:34:4    1.796    184.8       50.0          0.98  330.7
# 343072    2020-9-23 5:34:5    1.799    185.6       50.0          0.98  332.7
# 343073    2020-9-23 5:34:6    1.803    186.4       50.0          0.98  334.9
#
# [343074 rows x 6 columns]

# %%
odd_rows
# Out:
#        Date  Energy  Voltage  Frequency  Power Factor  Power
# 0       NaN   0.090      NaN        NaN           NaN    NaN
# 1       NaN   0.090      NaN        NaN           NaN    NaN
# 2       NaN   0.090      NaN        NaN           NaN    NaN
# 3       NaN   0.090      NaN        NaN           NaN    NaN
# 4       NaN   0.090      NaN        NaN           NaN    NaN
# ...     ...     ...      ...        ...           ...    ...
# 343069  NaN  15.654      NaN        NaN           NaN    NaN
# 343070  NaN  15.654      NaN        NaN           NaN    NaN
# 343071  NaN  15.654      NaN        NaN           NaN    NaN
# 343072  NaN  15.654      NaN        NaN           NaN    NaN
# 343073  NaN   1.000      NaN        NaN           NaN    NaN
#
# [343074 rows x 6 columns]

# %%
df1 = pd.concat([df, odd_rows], axis =1)

# %%
df1["Current"].value_counts()
# Out:
# 0.134    1933
# 0.136    1898
# 0.135    1812
# 0.133    1776
# 0.229    1562
#          ...
# 3.308       1
# 3.194       1
# 2.293       1
# 3.442       1
# 2.144       1
# Name: Current, Length: 3158, dtype: int64

# %%
df
# Out:
# 0        2020-12-20 12:39:01
# 1        2020-12-20 12:39:02
# 2        2020-12-20 12:39:03
# 3        2020-12-20 12:39:04
# 4        2020-12-20 12:39:05
#                  ...
# 343069   2020-09-23 05:34:02
# 343070   2020-09-23 05:34:03
# 343071   2020-09-23 05:34:04
# 343072   2020-09-23 05:34:05
# 343073   2020-09-23 05:34:06
# Name: Date, Length: 343074, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343074 entries, 0 to 343073
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          343074 non-null  object
#  1   Current       343070 non-null  float64
#  2   Voltage       343074 non-null  float64
#  3   Frequency     343074 non-null  float64
#  4   Power Factor  343074 non-null  float64
#  5   Power         343074 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 15.7+ MB

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.shape
# Out:
# (343074, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343074 entries, 0 to 343073
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date          343074 non-null  datetime64[ns]
#  1   Current       343070 non-null  float64
#  2   Voltage       343074 non-null  float64
#  3   Frequency     343074 non-null  float64
#  4   Power Factor  343074 non-null  float64
#  5   Power         343074 non-null  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 15.7 MB

# %%
df.Current.value_counts()
# Out:
# 0.134    1933
# 0.136    1898
# 0.135    1812
# 0.133    1776
# 0.229    1562
#          ...
# 3.308       1
# 3.194       1
# 2.293       1
# 3.442       1
# 2.144       1
# Name: Current, Length: 3158, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                       Date  Current  Voltage  Frequency  Power Factor  Power
# 4      2020-12-20 12:39:05    0.035    220.8       49.8          0.14    2.0
# 5      2020-12-20 12:39:06    0.037    220.7       49.8          0.19    2.8
# 6      2020-12-20 12:39:08    0.037    220.7       49.8          0.19    2.8
# 7      2020-12-20 12:39:09    0.036    220.6       49.8          0.20    2.9
# 8      2020-12-20 12:39:10    0.036    221.0       49.8          0.20    2.9
# ...                    ...      ...      ...        ...           ...    ...
# 343069 2020-09-23 05:34:02    1.813    188.3       50.0          0.98  340.1
# 343070 2020-09-23 05:34:03    1.801    185.6       50.0          0.98  333.0
# 343071 2020-09-23 05:34:04    1.796    184.8       50.0          0.98  330.7
# 343072 2020-09-23 05:34:05    1.799    185.6       50.0          0.98  332.7
# 343073 2020-09-23 05:34:06    1.803    186.4       50.0          0.98  334.9
#
# [343070 rows x 6 columns]

# %%
df.reset_index()
# Out:
#          index                Date  Current  Voltage  Frequency  Power Factor  \
# 0            4 2020-12-20 12:39:05    0.035    220.8       49.8          0.14
# 1            5 2020-12-20 12:39:06    0.037    220.7       49.8          0.19
# 2            6 2020-12-20 12:39:08    0.037    220.7       49.8          0.19
# 3            7 2020-12-20 12:39:09    0.036    220.6       49.8          0.20
# 4            8 2020-12-20 12:39:10    0.036    221.0       49.8          0.20
# ...        ...                 ...      ...      ...        ...           ...
# 343065  343069 2020-09-23 05:34:02    1.813    188.3       50.0          0.98
# 343066  343070 2020-09-23 05:34:03    1.801    185.6       50.0          0.98
# 343067  343071 2020-09-23 05:34:04    1.796    184.8       50.0          0.98
# 343068  343072 2020-09-23 05:34:05    1.799    185.6       50.0          0.98
# 343069  343073 2020-09-23 05:34:06    1.803    186.4       50.0          0.98
#
#         Power
# 0         2.0
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                       Date  Current  Voltage  Frequency  Power Factor  Power
# 0      2020-12-20 12:39:05    0.035    220.8       49.8          0.14    2.0
# 1      2020-12-20 12:39:06    0.037    220.7       49.8          0.19    2.8
# 2      2020-12-20 12:39:08    0.037    220.7       49.8          0.19    2.8
# 3      2020-12-20 12:39:09    0.036    220.6       49.8          0.20    2.9
# 4      2020-12-20 12:39:10    0.036    221.0       49.8          0.20    2.9
# ...                    ...      ...      ...        ...           ...    ...
# 343065 2020-09-23 05:34:02    1.813    188.3       50.0          0.98  340.1
# 343066 2020-09-23 05:34:03    1.801    185.6       50.0          0.98  333.0
# 343067 2020-09-23 05:34:04    1.796    184.8       50.0          0.98  330.7
# 343068 2020-09-23 05:34:05    1.799    185.6       50.0          0.98  332.7
# 343069 2020-09-23 05:34:06    1.803    186.4       50.0          0.98  334.9
#
# [343070 rows x 6 columns]

# %%
sns.boxplot(data = df, x = "Voltage")
# Out:
# <AxesSubplot:xlabel='Voltage'>

# %%
df2 = df[df.Voltage <= 150]

# %%
df2
# Out:
#                       Date  Current  Voltage  Frequency  Power Factor  Power
# 12133  2020-09-09 18:29:37    1.117    149.4       49.9          0.93  159.3
# 12362  2020-09-09 18:33:56    1.113    147.7       50.0          0.92  155.3
# 12364  2020-09-09 18:33:59    1.106    147.7       50.0          0.92  154.4
# 12404  2020-09-09 18:34:44    1.092    148.2       50.0          0.93  154.7
# 12405  2020-09-09 18:34:45    1.102    147.1       50.0          0.92  153.2
# ...                    ...      ...      ...        ...           ...    ...
# 326278 2020-09-22 17:40:37    0.206    133.8       50.1          0.80   25.3
# 326279 2020-09-22 17:40:39    0.206    134.8       50.2          0.80   25.5
# 326280 2020-09-22 17:40:40    0.206    135.1       50.2          0.80   25.5
# 326281 2020-09-22 17:40:41    0.208    135.4       50.2          0.79   25.5
# 326282 2020-09-22 17:40:42    0.206    135.6       50.2          0.80   25.6
#
# [40535 rows x 6 columns]

# %%
df2.
